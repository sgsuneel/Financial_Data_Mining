# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sp500 = pd.read_csv("data/sp500.csv", index_col='Symbol')
sp500.shape
# Out:
# (500, 14)

# %%
sp500.columns
# Out:
# Index(['Name', 'Sector', 'Price', 'Dividend Yield', 'Price/Earnings',
#        'Earnings/Share', 'Book Value', '52 week low', '52 week high',
#        'Market Cap', 'EBITDA', 'Price/Sales', 'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
sp500.dtypes
# Out:
# Name               object
# Sector             object
# Price             float64
# Dividend Yield    float64
# Price/Earnings    float64
# Earnings/Share    float64
# Book Value        float64
# 52 week low       float64
# 52 week high      float64
# Market Cap        float64
# EBITDA            float64
# Price/Sales       float64
# Price/Book        float64
# SEC Filings        object
# dtype: object

# %%
sp500.index
# Out:
# Index(['MMM', 'ABT', 'ABBV', 'ACN', 'ACE', 'ACT', 'ADBE', 'AES', 'AET', 'AFL',
#        ...
#        'XEL', 'XRX', 'XLNX', 'XL', 'XYL', 'YHOO', 'YUM', 'ZMH', 'ZION', 'ZTS'],
#       dtype='object', name='Symbol', length=500)

# %%
# Selecting columns of a dataframe
sp500[1:5].head()
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
# ACE              10.00          10.293      86.897        84.73        104.07
#
#         Market Cap  EBITDA  Price/Sales  Price/Book  \
# Symbol
# ABT         59.477   4.359         2.74        2.55
# ABBV        85.784   7.190         4.48       18.16
# ...

# %%
sp500[[1,3,6,9]].head(3)
# Out:
#              Sector  Dividend Yield  Book Value  Market Cap
# Symbol
# MMM     Industrials            2.12      26.668      92.345
# ABT     Health Care            1.82      15.573      59.477
# ABBV    Health Care            3.02       2.954      85.784

# %%
sp500['Price'].count()
# Out:
# 500

# %%
sp500[['Sector', 'Book Value', 'Market Cap']][:5]
# Out:
#                         Sector  Book Value  Market Cap
# Symbol
# MMM                Industrials      26.668      92.345
# ABT                Health Care      15.573      59.477
# ABBV               Health Care       2.954      85.784
# ACN     Information Technology       8.326      50.513
# ACE                 Financials      86.897      34.753

# %%
sp500[['Sector', 'Book Value', 'Market Cap']][-15:]
# Out:
#                              Sector  Book Value  Market Cap
# Symbol
# WFM                Consumer Staples      10.867      13.887
# WIN     Telecommunications Services       1.199       5.653
# WEC                       Utilities      19.165      10.178
# WYN          Consumer Discretionary      11.984       9.172
# WYNN         Consumer Discretionary      -0.719      20.957
# XEL                       Utilities      19.450      15.180
# XRX          Information Technology      10.471      14.078
# XLNX         Information Technology      10.247      12.373
# XL                       Financials      37.451       8.816
# XYL                     Industrials      12.127       7.061
# YHOO         Information Technology      12.768      35.258
# YUM          Consumer Discretionary       5.147      33.002
# ZMH                     Health Care      37.181      17.091
# ZION                     Financials      30.191       5.257
# ...

# %%
sp500['XYL':'ZTS']['Name']
# Out:
# Symbol
# XYL          Xylem Inc.
# YHOO         Yahoo Inc.
# YUM     Yum! Brands Inc
# ZMH     Zimmer Holdings
# ZION      Zions Bancorp
# ZTS          Zoetis Inc
# Name: Name, dtype: object

# %%
sp500[:5]['Name']
# Out:
# Symbol
# MMM                  3M Co.
# ABT     Abbott Laboratories
# ABBV            AbbVie Inc.
# ACN               Accenture
# ACE             ACE Limited
# Name: Name, dtype: object

# %%
sp500['MMM':'ACE']
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
# ACE             ACE Limited              Financials  102.91            2.21
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
# ACE              10.00          10.293      86.897        84.73        104.07
#
# ...

# %%
sp500.loc['MMM':'ACN']
# Out:
#                        Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM                  3M Co.             Industrials  141.14            2.12
# ABT     Abbott Laboratories             Health Care   39.60            1.82
# ABBV            AbbVie Inc.             Health Care   53.95            3.02
# ACN               Accenture  Information Technology   79.79            2.34
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABT              25.93           1.529      15.573        32.70         40.49
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
#
#         Market Cap  EBITDA  Price/Sales  Price/Book  \
# Symbol
# MMM         92.345   8.121         2.95        5.26
# ABT         59.477   4.359         2.74        2.55
# ...

# %%
sp500.loc['MMM']
# Out:
# Name                                                         3M Co.
# Sector                                                  Industrials
# Price                                                        141.14
# Dividend Yield                                                 2.12
# Price/Earnings                                                20.33
# Earnings/Share                                                  6.9
# Book Value                                                   26.668
# 52 week low                                                  107.15
# 52 week high                                                 143.37
# Market Cap                                                   92.345
# EBITDA                                                        8.121
# Price/Sales                                                    2.95
# Price/Book                                                     5.26
# SEC Filings       http://www.sec.gov/cgi-bin/browse-edgar?action...
# ...

# %%
sp500.loc[['MMM','ABBV','ACN']]
# Out:
#                Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM          3M Co.             Industrials  141.14            2.12
# ABBV    AbbVie Inc.             Health Care   53.95            3.02
# ACN       Accenture  Information Technology   79.79            2.34
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ABBV             20.87           2.570       2.954        40.10         54.78
# ACN              19.53           4.068       8.326        69.00         85.88
#
#         Market Cap  EBITDA  Price/Sales  Price/Book  \
# Symbol
# MMM         92.345   8.121         2.95        5.26
# ABBV        85.784   7.190         4.48       18.16
# ACN         50.513   4.423         1.75        9.54
#
#                                               SEC Filings
# Symbol
# MMM     http://www.sec.gov/cgi-bin/browse-edgar?action...
# ...

# %%
sp500.iloc[[0,2]]
# Out:
#                Name       Sector   Price  Dividend Yield  Price/Earnings  \
# Symbol
# MMM          3M Co.  Industrials  141.14            2.12           20.33
# ABBV    AbbVie Inc.  Health Care   53.95            3.02           20.87
#
#         Earnings/Share  Book Value  52 week low  52 week high  Market Cap  \
# Symbol
# MMM               6.90      26.668       107.15        143.37      92.345
# ABBV              2.57       2.954        40.10         54.78      85.784
#
#         EBITDA  Price/Sales  Price/Book  \
# Symbol
# MMM      8.121         2.95        5.26
# ABBV     7.190         4.48       18.16
#
#                                               SEC Filings
# Symbol
# MMM     http://www.sec.gov/cgi-bin/browse-edgar?action...
# ABBV    http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
# lets get the location of the required labels
i1 = sp500.index.get_loc('MMM')
i2 = sp500.index.get_loc('ACN')
i1, i2
# Out:
# (0, 3)

# %%
sp500.iloc[[i1,i2]]
# Out:
#              Name                  Sector   Price  Dividend Yield  \
# Symbol
# MMM        3M Co.             Industrials  141.14            2.12
# ACN     Accenture  Information Technology   79.79            2.34
#
#         Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# Symbol
# MMM              20.33           6.900      26.668       107.15        143.37
# ACN              19.53           4.068       8.326        69.00         85.88
#
#         Market Cap  EBITDA  Price/Sales  Price/Book  \
# Symbol
# MMM         92.345   8.121         2.95        5.26
# ACN         50.513   4.423         1.75        9.54
#
#                                               SEC Filings
# Symbol
# MMM     http://www.sec.gov/cgi-bin/browse-edgar?action...
# ACN     http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
sp500.ix[['MMM','zts','ZTS']]
# Out:
#               Name       Sector   Price  Dividend Yield  Price/Earnings  \
# Symbol
# MMM         3M Co.  Industrials  141.14            2.12           20.33
# zts            NaN          NaN     NaN             NaN             NaN
# ZTS     Zoetis Inc  Health Care   30.53            0.90           29.22
#
#         Earnings/Share  Book Value  52 week low  52 week high  Market Cap  \
# Symbol
# MMM              6.900      26.668       107.15        143.37      92.345
# zts                NaN         NaN          NaN           NaN         NaN
# ZTS              1.038       2.150        28.14         34.28      15.296
#
#         EBITDA  Price/Sales  Price/Book  \
# Symbol
# MMM      8.121         2.95        5.26
# zts        NaN          NaN         NaN
# ZTS      1.292         3.33       14.11
#
#                                               SEC Filings
# Symbol
# MMM     http://www.sec.gov/cgi-bin/browse-edgar?action...
# zts                                                   NaN
# ...

# %%
sp500.iat[0,1] # .iat[row location, column location]
# Out:
# 'Industrials'

# %%
sp500.at['MMM', 'Price']
# Out:
# 141.13999999999999

# %%
sp500.Price < 500
# Out:
# Symbol
# MMM     True
# ABT     True
# ABBV    True
# ACN     True
# ACE     True
# ACT     True
# ADBE    True
# AES     True
# AET     True
# AFL     True
# A       True
# GAS     True
# APD     True
# ARG     True
# AKAM    True
# AA      True
# ALXN    True
# ATI     True
# ALLE    True
# AGN     True
# ADS     True
# ALL     True
# ALTR    True
# MO      True
# AMZN    True
# AEE     True
# AEP     True
# AXP     True
# AIG     True
# AMT     True
#         ...
# VIAB    True
# V       True
# VNO     True
# VMC     True
# WMT     True
# WAG     True
# DIS     True
# WM      True
# WAT     True
# WLP     True
# WFC     True
# WDC     True
# WU      True
# WY      True
# WHR     True
# WFM     True
# WIN     True
# WEC     True
# WYN     True
# WYNN    True
# XEL     True
# XRX     True
# XLNX    True
# XL      True
# XYL     True
# YHOO    True
# YUM     True
# ZMH     True
# ZION    True
# ZTS     True
# Name: Price, dtype: bool

# %%
sp500[sp500.Price<100]
# Out:
#                                 Name                       Sector  Price  \
# Symbol
# ABT              Abbott Laboratories                  Health Care  39.60
# ABBV                     AbbVie Inc.                  Health Care  53.95
# ACN                        Accenture       Information Technology  79.79
# ADBE               Adobe Systems Inc       Information Technology  64.30
# AES                         AES Corp                    Utilities  13.61
# AET                        Aetna Inc                  Health Care  76.39
# AFL                        AFLAC Inc                   Financials  61.31
# A           Agilent Technologies Inc                  Health Care  56.18
# GAS               AGL Resources Inc.                    Utilities  52.98
# AKAM         Akamai Technologies Inc       Information Technology  53.65
# AA                         Alcoa Inc                    Materials  13.52
# ATI       Allegheny Technologies Inc                    Materials  40.99
# ...

# %%
sp500[(sp500.Price<100) & (sp500.Price>0)][['Price']]
# Out:
#         Price
# Symbol
# ABT     39.60
# ABBV    53.95
# ACN     79.79
# ADBE    64.30
# AES     13.61
# AET     76.39
# AFL     61.31
# A       56.18
# GAS     52.98
# AKAM    53.65
# AA      13.52
# ATI     40.99
# ALLE    52.46
# ALL     58.38
# ALTR    33.31
# MO      40.68
# AEE     38.64
# AEP     51.41
# AXP     88.78
# AIG     53.60
# AMT     88.41
# ABC     71.64
# AME     52.49
# APH     95.71
# ADI     52.39
# AON     88.43
# APA     90.18
# AIV     31.24
# AMAT    20.04
# ADM     43.56
# ...       ...
# VLO     54.54
# VAR     80.92
# VTR     67.03
# VRSN    49.92
# VZ      49.74
# VRTX    71.04
# VFC     62.72
# VIAB    84.99
# VMC     61.19
# WMT     75.61
# WAG     69.79
# DIS     83.32
# WM      43.37
# WFC     50.16
# WDC     84.83
# WU      15.77
# WY      30.87
# WFM     37.78
# WIN      9.38
# WEC     45.13
# WYN     72.22
# XEL     30.24
# XRX     12.06
# XLNX    46.03
# XL      32.47
# XYL     38.42
# YHOO    35.02
# YUM     74.77
# ZION    28.43
# ...
